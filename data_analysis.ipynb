# %%
import pandas as pd

# %%
arxiv_data = pd.read_json(r'data_accessing/arxiv_papers_int_aerospace.jsonl', orient='records', lines=True)
openalex_enriched_data = pd.read_json(r'data_accessing/arxivANDopenalex_papers_int_aerospace.jsonl', orient='records', lines=True)

# %%
arxiv_data
# Out:
#                                   arxiv_id                      doi  \
# 0  http://arxiv.org/abs/astro-ph/9404062v1  10.1093/mnras/270.3.611
# 1        http://arxiv.org/abs/cs/9605104v1                     None
# 2  http://arxiv.org/abs/astro-ph/9702168v3                     None
# 3  http://arxiv.org/abs/astro-ph/9704012v1                     None
# 4  http://arxiv.org/abs/astro-ph/9711315v1                     None
# 5  http://arxiv.org/abs/astro-ph/9805211v1                     None
# 6  http://arxiv.org/abs/astro-ph/9808192v1                     None
# 7  http://arxiv.org/abs/astro-ph/9809104v1                     None
# 8  http://arxiv.org/abs/astro-ph/9907237v1                     None
# 9  http://arxiv.org/abs/astro-ph/9910074v1           10.1086/301192
#
#                                                title  \
# 0  Resonant Oscillations and Tidal Heating in Coa...
# 1  Adaptive Problem-solving for Large-scale Sched...
# 2  Results from GROCSE: A Real-time Search for Ga...
# 3  Galaxy Morphology Without Classification: Self...
# 4  Search for Extra-Solar Planets Through Monitor...
# 5      ASCA Observation of the polar RX J1802.1+1804
# 6  S 10943 Vulpeculae: A New ROSAT Selected Dwarf...
# 7  RX J1016.9-4103: A new soft X-ray polar in the...
# 8  Modeling Encounters of Galaxies: The Case of N...
# 9  HST/WFPC2 and VLT/ISAAC observations of PROPLY...
#
#                                              summary             published  \
# 0  Tidal interaction in a coalescing neutron star...  1994-04-25T01:31:08Z
# 1  Although most scheduling problems are NP-hard,...  1996-05-01T00:00:00Z
# 2  The Gamma-Ray Optical Counterpart Search Exper...  1997-02-19T20:18:22Z
# 3  We examine a general framework for visualizing...  1997-04-01T18:35:54Z
# 4  During the months when the galactic bulge is v...  1997-11-26T14:58:54Z
# 5  We present X-ray data of RX J1802.1+1804 obtai...  1998-05-15T12:19:12Z
# 6  We have identified the ROSAT all-sky survey so...  1998-08-19T11:56:47Z
# 7  We have discovered a new AM Her system as the ...  1998-09-09T07:16:32Z
# 8  (abridged) Several N-body methods were combine...  1999-07-17T16:04:20Z
# 9  We report the discovery of three proplyd-like ...  1999-10-05T01:25:42Z
#
#                 updated                                            authors  \
# 0  1994-04-25T01:31:08Z                                         [Dong Lai]
# 1  1996-05-01T00:00:00Z                              [J. Gratch, S. Chien]
# 2  1997-04-01T02:50:32Z  [Brian Lee, Carl Akerlof, David Band, Scott Ba...
# 3  1997-04-01T18:35:54Z       [A. Naim, K. U. Ratnatunga, R. E. Griffiths]
# 4  1997-11-26T14:58:54Z                                  [Kailash C. Sahu]
# 5  1998-05-15T12:19:12Z  [M. Ishida, J. Greiner, R. A. Remillard, C. Mo...
# 6  1998-08-19T11:56:47Z              [G. A. Richter, J. Greiner, P. Kroll]
# 7  1998-09-09T07:16:32Z                   [Jochen Greiner, Robert Schwarz]
# 8  1999-07-17T16:04:20Z                                  [Christian Theis]
# 9  1999-10-05T01:25:42Z  [W. Brandner, E. K. Grebel, Y. -H. Chu, H. Dot...
#
#                                       link  \
# 0  http://arxiv.org/abs/astro-ph/9404062v1
# 1        http://arxiv.org/abs/cs/9605104v1
# 2  http://arxiv.org/abs/astro-ph/9702168v3
# 3  http://arxiv.org/abs/astro-ph/9704012v1
# 4  http://arxiv.org/abs/astro-ph/9711315v1
# 5  http://arxiv.org/abs/astro-ph/9805211v1
# 6  http://arxiv.org/abs/astro-ph/9808192v1
# 7  http://arxiv.org/abs/astro-ph/9809104v1
# 8  http://arxiv.org/abs/astro-ph/9907237v1
# 9  http://arxiv.org/abs/astro-ph/9910074v1
#
#                                              journal    category  \
# 0             Mon.Not.Roy.Astron.Soc. 270 (1994) 611  [astro-ph]
# 1  Journal of Artificial Intelligence Research, V...     [cs.AI]
# 2                                               None  [astro-ph]
# 3                                               None  [astro-ph]
# 4                                               None  [astro-ph]
# 5                      Astron.Astrophys.336:200,1998  [astro-ph]
# 6                                               None  [astro-ph]
# 7                                               None  [astro-ph]
# 8                                               None  [astro-ph]
# 9                                               None  [astro-ph]
#
#                                   pdf_link  \
# 0  http://arxiv.org/pdf/astro-ph/9404062v1
# 1        http://arxiv.org/pdf/cs/9605104v1
# 2  http://arxiv.org/pdf/astro-ph/9702168v3
# 3  http://arxiv.org/pdf/astro-ph/9704012v1
# 4  http://arxiv.org/pdf/astro-ph/9711315v1
# 5  http://arxiv.org/pdf/astro-ph/9805211v1
# 6  http://arxiv.org/pdf/astro-ph/9808192v1
# 7  http://arxiv.org/pdf/astro-ph/9809104v1
# 8  http://arxiv.org/pdf/astro-ph/9907237v1
# 9  http://arxiv.org/pdf/astro-ph/9910074v1
#
#                                            full_text
# 0  arXiv:astro-ph/9404062v1  25 Apr 1994\nRESONAN...
# 1  Journal of Artificial Intelligence Research 4 ...
# 2  arXiv:astro-ph/9702168v3  1 Apr 1997\nResults ...
# 3  arXiv:astro-ph/9704012v1  1 Apr 1997\nGALAXY M...
# 4  arXiv:astro-ph/9711315v1  26 Nov 1997\nSEARCH ...
# 5  arXiv:astro-ph/9805211v1  15 May 1998\nA&A man...
# 6  arXiv:astro-ph/9808192v1  19 Aug 1998\nCOMMISS...
# 7  arXiv:astro-ph/9809104v1  9 Sep 1998\nA&A manu...
# 8  arXiv:astro-ph/9907237v1  17 Jul 1999\nModelin...
# 9  arXiv:astro-ph/9910074v1  5 Oct 1999\nDraft ve...

# %%
openalex_enriched_data
# Out:
#                                   arxiv_id                      doi  \
# 0  http://arxiv.org/abs/astro-ph/9404062v1  10.1093/mnras/270.3.611
# 1  http://arxiv.org/abs/astro-ph/9910074v1           10.1086/301192
#
#                                                title  \
# 0  Resonant Oscillations and Tidal Heating in Coa...
# 1  HST/WFPC2 and VLT/ISAAC observations of PROPLY...
#
#                                              summary             published  \
# 0  Tidal interaction in a coalescing neutron star...  1994-04-25T01:31:08Z
# 1  We report the discovery of three proplyd-like ...  1999-10-05T01:25:42Z
#
#                 updated                                            authors  \
# 0  1994-04-25T01:31:08Z                                         [Dong Lai]
# 1  1999-10-05T01:25:42Z  [W. Brandner, E. K. Grebel, Y. -H. Chu, H. Dot...
#
#                                       link  \
# 0  http://arxiv.org/abs/astro-ph/9404062v1
# 1  http://arxiv.org/abs/astro-ph/9910074v1
#
#                                   journal    category  \
# 0  Mon.Not.Roy.Astron.Soc. 270 (1994) 611  [astro-ph]
# 1                                    None  [astro-ph]
#
#                                   pdf_link  \
# 0  http://arxiv.org/pdf/astro-ph/9404062v1
# 1  http://arxiv.org/pdf/astro-ph/9910074v1
#
#                                            full_text  \
# 0  arXiv:astro-ph/9404062v1  25 Apr 1994\nRESONAN...
# 1  arXiv:astro-ph/9910074v1  5 Oct 1999\nDraft ve...
#
#                         openalex_id  \
# 0  https://openalex.org/W2149923070
# 1  https://openalex.org/W1978659579
#
#                                             concepts  cited_by_count  \
# 0  [{'id': 'https://openalex.org/C121332964', 'wi...             225
# 1  [{'id': 'https://openalex.org/C44870925', 'wik...              59
#
#    host_venue  open_access
# 0         NaN         True
# 1         NaN         True
